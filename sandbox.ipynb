# %% [markdown]
# # Sandbox
#
# This is a helper python notebook you can use to debug and try things during the workshop.

# %%
from example_agent.graph import graph

from IPython.display import Image, display

display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
res = graph.invoke({"messages": [
    """
    In order to survive the trail ahead, you'll need to have a restocking strategy for when you need to get more supplies or risk starving. If it takes you an estimated 3 days to restock your food and you plan to start with 200lbs of food, budget 10lbs/day to eat, and keep a safety stock of at least 50lbs of back up... at what point should you restock?
    
    Options: A: 100lbs, B: 20lbs, C: 5lbs, D: 80lbs
    """
]})
# Out:
# Using restock tool!: daily_usage=10, lead_time=3, safety_stock=50
# In multi_choice structured:
#     In order to survive the trail ahead, you'll need to have a restocking strategy for when you need to get more supplies or risk starving. If it takes you an estimated 3 days to restock your food and you plan to start with 200lbs of food, budget 10lbs/day to eat, and keep a safety stock of at least 50lbs of back up... at what point should you restock?
#
#     Options: A: 100lbs, B: 20lbs, C: 5lbs, D: 80lbs
#
#
#
# In multi_choice structured:  80

# %%
res["multi_choice_response"]
# Out:
# 'D'

# %%
"Options:" in """    In order to survive the trail ahead, you'll need to have a restocking strategy for when you need to get more supplies or risk starving. If it takes you an estimated 3 days to restock your food and you plan to start with 200lbs of food, budget 10lbs/day to eat, and keep a safety stock of at least 50lbs of back up... at what point should you restock?
    
    Options: A: 100lbs, B: 20lbs, C: 5lbs, D: 80lbs"""
# Out:
# True

# %%
"cat" in "brown cat"
# Out:
# True

# %%
"Cat".lower()
# Out:
# 'cat'
